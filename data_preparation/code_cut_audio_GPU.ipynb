# %% [markdown]
# ### Code chuẩn

# %%
import os
import whisperx
from pydub import AudioSegment
import shutil
import torch
import csv
import gc

# --- CẤU HÌNH MÔI TRƯỜNG ---
venv_path = os.path.join(os.getcwd(), "venv", "Lib", "site-packages", "nvidia", "cublas", "bin")
if os.path.exists(venv_path):
    os.environ["PATH"] += os.pathsep + venv_path

ffmpeg_path = r"D:\Speech_Verification\SpeechVeri_MultiFeatures\data_preparation\ffmpeg.exe"
ffprobe_path = r"D:\Speech_Verification\SpeechVeri_MultiFeatures\data_preparation\ffprobe.exe" 
ffmpeg_dir = os.path.dirname(ffmpeg_path)

# Thêm ffmpeg folder vào PATH
os.environ["PATH"] = ffmpeg_dir + os.pathsep + os.environ["PATH"]

AudioSegment.converter = ffmpeg_path
AudioSegment.ffprobe = ffprobe_path

# Fix torch.load + omegaconf (PyTorch 2.6+ weights_only issue)
import warnings
warnings.filterwarnings("ignore")

try:
    from omegaconf import ListConfig, DictConfig
    if hasattr(torch.serialization, 'add_safe_globals'):
        torch.serialization.add_safe_globals([ListConfig, DictConfig])
except:
    pass

# Patch torch.load để tránh weights_only error
_original_torch_load = torch.load
def _custom_torch_load(*args, **kwargs):
    kwargs['weights_only'] = False
    return _original_torch_load(*args, **kwargs)
torch.load = _custom_torch_load

# --- CẤU HÌNH ---
input_dir = r"D:\my_project\SLP301-data\test_data\test_set_O\wav"
output_dir = r"D:\my_project\SLP301-data\test_data\test_set_O\3s"
english_dir = r"D:\my_project\SLP301-data\other_language_files"

# Kiểm tra input_dir tồn tại
if not os.path.exists(input_dir):
    print(f"❌ Input folder không tồn tại: {input_dir}")
else:
    print(f"✓ Tìm thấy {len([f for f in os.listdir(input_dir) if f.lower().endswith(('.wav', '.mp3'))])} file audio")

os.makedirs(output_dir, exist_ok=True)
os.makedirs(english_dir, exist_ok=True)

MODEL_SIZE = "large-v2" 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
COMPUTE_TYPE = "float16" if DEVICE == "cuda" else "int8"

TARGET_SECONDS = 3.0
STRIDE_SECONDS = 3.0 
MARGIN = 0.5
MIN_DUR = TARGET_SECONDS - MARGIN 
MAX_DUR = TARGET_SECONDS + MARGIN 

# Metadata
meta_path = os.path.join(output_dir, "metadata.csv")
meta_exists = os.path.exists(meta_path)
meta_file = open(meta_path, "a", newline="", encoding="utf-8")
writer = csv.writer(meta_file)
if not meta_exists:
    writer.writerow(["target_duration", "speaker_id", "filename", "lang", "duration", "start", "end", "text"])
    meta_file.flush()

print(f"Loading Whisper {MODEL_SIZE} on {DEVICE}...")
model = whisperx.load_model(MODEL_SIZE, device=DEVICE, compute_type=COMPUTE_TYPE)
align_models = {}

# --- [HÀM MỚI] KIỂM TRA TEXT RÁC (LẶP TỪ) ---
def is_valid_text(words_list):
    if not words_list: return False
    
    # Lấy danh sách các từ (bỏ qua dấu câu cơ bản nếu cần)
    text_content = [w["word"].strip().lower() for w in words_list]
    
    # 1. Kiểm tra độ đa dạng của từ (Unique Ratio)
    # Ví dụ: "con con con con" -> 4 từ, nhưng chỉ có 1 từ duy nhất -> Ratio = 0.25 -> RÁC
    unique_words = set(text_content)
    unique_ratio = len(unique_words) / len(text_content)
    
    if len(text_content) > 3 and unique_ratio < 0.4:
        return False # Quá nhiều từ lặp lại
        
    return True
# ---------------------------------------------

print(f"\n>>> CHẾ ĐỘ: CỬA SỔ TRƯỢT INDEX + LỌC RÁC + MEMORY OPTIMIZATION <<<")

# --- CHECKPOINT: QUÉT NHỮNG FILE ĐÃ CẮT ---
processed_files = set()
if os.path.exists(output_dir):
    for out_file in os.listdir(output_dir):
        if "_seg_" in out_file and out_file.endswith(".wav"):
            # Extract base_name từ file như: "sp001_seg_001.wav" -> "sp001"
            base_name = out_file.split("_seg_")[0]
            processed_files.add(base_name)

if processed_files:
    print(f"✓ Đã xử lý: {len(processed_files)} file gốc")
    print(f"  Danh sách: {', '.join(sorted(processed_files)[:10])}" + ("..." if len(processed_files) > 10 else ""))
else:
    print("• Chưa xử lý file nào, bắt đầu từ đầu")
# ---

try:
    for filename in os.listdir(input_dir):
        if not filename.lower().endswith((".wav", ".mp3")): continue
        
        base_name = os.path.splitext(filename)[0]
        
        # SKIP nếu file đã xử lý
        if base_name in processed_files:
            print(f"⊘ Bỏ qua (đã xử lý): {filename}")
            continue
        
        print(f"\n--- Xử lý: {filename} ---")
        input_path = os.path.join(input_dir, filename)
        speaker_id = base_name.split("_")[0]

        try:
            # 1. Transcribe
            audio_data = whisperx.load_audio(input_path)
            result = model.transcribe(audio_data, batch_size=16)
            detected_lang = result.get("language", "unknown")
            
            # [FIX] Clear intermediate tensors từ audio
            del audio_data
            gc.collect()
            torch.cuda.empty_cache()

            if detected_lang == "en":
                shutil.copy(input_path, os.path.join(english_dir, filename))
                processed_files.add(base_name)  # Mark as processed
                del result
                gc.collect()
                torch.cuda.empty_cache()
                continue 

            if detected_lang not in align_models:
                if detected_lang == "vi":
                    align_models[detected_lang] = whisperx.load_align_model(language_code="vi", device=DEVICE, model_name="nguyenvulebinh/wav2vec2-base-vi")
                else:
                    align_models[detected_lang] = whisperx.load_align_model(language_code=detected_lang, device=DEVICE)
            
            result_aligned = whisperx.align(result["segments"], align_models[detected_lang][0], align_models[detected_lang][1], input_path, DEVICE)
            words = [w for w in result_aligned["word_segments"] if "start" in w and "end" in w]
            
            # [FIX] Clear result objects ngay sau khi extract words
            del result, result_aligned
            gc.collect()
            torch.cuda.empty_cache()

            if not words:
                processed_files.add(base_name)  # Mark as processed even if no words
                del words
                gc.collect()
                torch.cuda.empty_cache()
                continue

            # 2. CẮT AUDIO (Index-Based)
            audio = AudioSegment.from_file(input_path)
            start_word_idx = 0
            seg_index = 1
            
            while start_word_idx < len(words):
                actual_start_time = words[start_word_idx]["start"]
                end_word_idx = None
                valid_segment_found = False
                
                # A. Gom từ
                for j in range(start_word_idx, len(words)):
                    current_word = words[j]
                    current_dur = current_word["end"] - actual_start_time
                    
                    if current_dur > MAX_DUR: break 
                    if current_dur >= MIN_DUR:
                        end_word_idx = j
                        valid_segment_found = True
                        break 

                # B. Xuất file (CÓ THÊM BƯỚC CHECK RÁC)
                if valid_segment_found and end_word_idx is not None:
                    current_segment_words = words[start_word_idx : end_word_idx + 1]
                    
                    # --- [FIX MỚI] CHECK LẶP TỪ ---
                    if is_valid_text(current_segment_words):
                        final_dur = current_segment_words[-1]["end"] - actual_start_time
                        start_ms = int(actual_start_time * 1000)
                        end_ms = int(current_segment_words[-1]["end"] * 1000)
                        
                        seg_audio = audio[start_ms:end_ms]
                        out_name = f"{base_name}_seg_{seg_index:03d}.wav"
                        seg_audio.export(os.path.join(output_dir, out_name), format="wav")
                        
                        text_seg = " ".join([w["word"].strip() for w in current_segment_words])
                        writer.writerow([
                            TARGET_SECONDS, speaker_id, out_name, detected_lang, 
                            round(final_dur, 3), 
                            round(actual_start_time, 3), 
                            round(current_segment_words[-1]["end"], 3), 
                            text_seg
                        ])
                        meta_file.flush()
                        seg_index += 1
                        
                        # [FIX] Clear segment audio objects
                        del seg_audio
                    else:
                        pass 
                        # print(f"-> Bỏ qua đoạn rác (Lặp từ): {actual_start_time}s")

                # C. Sliding Window (Index)
                next_start_idx = None
                desired_next_time = actual_start_time + STRIDE_SECONDS
                for k in range(start_word_idx + 1, len(words)):
                    if words[k]["start"] >= desired_next_time:
                        next_start_idx = k
                        break
                
                if next_start_idx is None: break 
                start_word_idx = next_start_idx
            
            # [FIX] Clear audio object sau khi xử lý xong file
            del audio, words
            gc.collect()
            torch.cuda.empty_cache()

            print(f"-> Đã lưu: {seg_index-1} file.")
            processed_files.add(base_name)  # Mark file as fully processed

        except Exception as e:
            print(f"Lỗi {filename}: {e}")
            # [FIX] Clear objects even on error
            gc.collect()
            torch.cuda.empty_cache()

finally:
    meta_file.close()
    print("\n>>> HOÀN TẤT <<<")
    # [FIX] Final cleanup
    del model, align_models
    gc.collect()
    torch.cuda.empty_cache()
# Out:
# ✓ Tìm thấy 20168 file audio
# Loading Whisper large-v2 on cpu...
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.5.1.post0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint c:\Users\PC1\anaconda3\envs\whisperx_env\lib\site-packages\whisperx\assets\pytorch_model.bin`
# No language specified, language will be first be detected for each audio file (increases inference time).
# >>Performing voice activity detection using Pyannote...
# Model was trained with pyannote.audio 0.0.1, yours is 3.3.2. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.7.0+cpu. Bad things might happen unless you revert torch to 1.x.
#
# >>> CHẾ ĐỘ: CỬA SỔ TRƯỢT INDEX + LỌC RÁC + MEMORY OPTIMIZATION <<<
# • Chưa xử lý file nào, bắt đầu từ đầu
#
# --- Xử lý: audio00001.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at nguyenvulebinh/wav2vec2-base-vi and are newly initialized: ['lm_head.bias', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00002.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00003.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00004.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00005.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00006.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00007.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00008.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00009.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00010.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00011.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00012.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00013.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00014.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00015.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00016.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00017.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00018.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00019.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00020.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00021.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00022.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00023.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00024.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00025.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00026.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00027.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00028.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00029.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00030.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00031.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00032.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00033.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00034.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00035.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00036.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00037.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00038.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00039.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00040.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00041.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00042.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00043.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00044.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00045.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00046.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00047.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00048.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00049.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00050.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00051.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00052.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00053.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00054.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00055.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00056.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00057.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00058.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.97) in first 30s of audio...
#
# --- Xử lý: audio00059.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00060.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00061.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00062.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00063.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00064.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00065.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00066.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00067.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00068.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00069.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00070.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00071.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00072.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00073.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00074.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00075.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00076.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00077.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00078.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00079.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00080.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00081.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00082.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00083.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00084.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00085.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00086.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00087.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00088.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00089.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00090.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00091.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00092.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00093.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00094.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00095.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00096.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00097.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00098.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00099.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00100.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00101.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00102.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.96) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00103.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00104.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00105.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00106.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00107.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00108.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00109.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00110.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00111.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00112.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00113.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00114.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00115.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00116.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.97) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00117.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00118.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00119.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00120.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00121.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00122.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00123.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00124.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00125.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00126.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00127.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00128.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00129.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00130.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00131.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00132.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 3 file.
#
# --- Xử lý: audio00133.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00134.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00135.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00136.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 3 file.
#
# --- Xử lý: audio00137.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00138.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00139.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00140.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00141.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00142.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00143.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00144.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00145.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00146.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00147.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00148.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00149.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00150.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00151.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00152.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00153.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00154.wav ---
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 8 file.
#
# --- Xử lý: audio00155.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00156.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#
# --- Xử lý: audio00157.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00158.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#
# --- Xử lý: audio00159.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00160.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00161.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00162.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 4 file.
#
# --- Xử lý: audio00163.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00164.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.94) in first 30s of audio...
# -> Đã lưu: 4 file.
#
# --- Xử lý: audio00165.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00166.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00167.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00168.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.92) in first 30s of audio...
# -> Đã lưu: 3 file.
#
# --- Xử lý: audio00169.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00170.wav ---
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 6 file.
#
# --- Xử lý: audio00171.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00172.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#
# --- Xử lý: audio00173.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00174.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
# -> Đã lưu: 3 file.
#
# --- Xử lý: audio00175.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00176.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00177.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00178.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00179.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00180.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#
# --- Xử lý: audio00181.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00182.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#
# --- Xử lý: audio00183.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00184.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
# -> Đã lưu: 4 file.
#
# --- Xử lý: audio00185.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00186.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00187.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00188.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 3 file.
#
# --- Xử lý: audio00189.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00190.wav ---
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 8 file.
#
# --- Xử lý: audio00191.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00192.wav ---
# Detected language: vi (0.94) in first 30s of audio...
# -> Đã lưu: 11 file.
#
# --- Xử lý: audio00193.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00194.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.94) in first 30s of audio...
# -> Đã lưu: 3 file.
#
# --- Xử lý: audio00195.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00196.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#
# --- Xử lý: audio00197.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00198.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#
# --- Xử lý: audio00199.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00200.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.94) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00201.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00202.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00203.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00204.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#
# --- Xử lý: audio00205.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00206.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.98) in first 30s of audio...
#
# --- Xử lý: audio00207.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00208.wav ---
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 12 file.
#
# --- Xử lý: audio00209.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00210.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#
# --- Xử lý: audio00211.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00212.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#
# --- Xử lý: audio00213.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00214.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00215.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00216.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#
# --- Xử lý: audio00217.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00218.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#
# --- Xử lý: audio00219.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00220.wav ---
# Detected language: vi (0.97) in first 30s of audio...
# -> Đã lưu: 9 file.
#
# --- Xử lý: audio00221.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00222.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#
# --- Xử lý: audio00223.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00224.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#
# --- Xử lý: audio00225.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00226.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#
# --- Xử lý: audio00227.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00228.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#
# --- Xử lý: audio00229.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00230.wav ---
# Detected language: vi (0.94) in first 30s of audio...
# -> Đã lưu: 8 file.
#
# --- Xử lý: audio00231.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00232.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00233.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00234.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00235.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00236.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#
# --- Xử lý: audio00237.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00238.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.91) in first 30s of audio...
# -> Đã lưu: 9 file.
#
# --- Xử lý: audio00239.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00240.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.97) in first 30s of audio...
# -> Đã lưu: 3 file.
#
# --- Xử lý: audio00241.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00242.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00243.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00244.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.92) in first 30s of audio...
# -> Đã lưu: 3 file.
#
# --- Xử lý: audio00245.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00246.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#
# --- Xử lý: audio00247.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00248.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.97) in first 30s of audio...
#
# --- Xử lý: audio00249.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00250.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.93) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00251.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 7 file.
#
# --- Xử lý: audio00252.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 4 file.
#
# --- Xử lý: audio00253.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00254.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00255.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00256.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00257.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00258.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00259.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00260.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00261.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00262.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 2 file.
#
# --- Xử lý: audio00263.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00264.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00265.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00266.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00267.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio00268.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio00269.wav ---
# ...
# Detected language: fr (0.60) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01513.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01514.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.31) in first 30s of audio...
#
# --- Xử lý: audio01515.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01516.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.89) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01517.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01518.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: fr (0.40) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01519.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01520.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.88) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01521.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01522.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01523.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01524.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: ja (0.80) in first 30s of audio...
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01525.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01526.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.26) in first 30s of audio...
#
# --- Xử lý: audio01527.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01528.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: ja (0.29) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01529.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01530.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: zh (0.21) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01531.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01532.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.94) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01533.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01534.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.31) in first 30s of audio...
#
# --- Xử lý: audio01535.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01536.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: zh (0.43) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio01537.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01538.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.12) in first 30s of audio...
#
# --- Xử lý: audio01539.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01540.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01541.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01542.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: fr (0.43) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01543.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01544.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: pt (0.22) in first 30s of audio...
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01545.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01546.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: fr (0.48) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01547.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01548.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.68) in first 30s of audio...
#
# --- Xử lý: audio01549.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01550.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01551.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01552.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.83) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio01553.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01554.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: pt (0.35) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01555.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01556.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: ko (0.74) in first 30s of audio...
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01557.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01558.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: zh (0.57) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01559.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01560.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: ar (0.83) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01561.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01562.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.27) in first 30s of audio...
#
# --- Xử lý: audio01563.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01564.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.91) in first 30s of audio...
# -> Đã lưu: 1 file.
#
# --- Xử lý: audio01565.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01566.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: zh (0.57) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01567.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01568.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.18) in first 30s of audio...
#
# --- Xử lý: audio01569.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01570.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: zh (0.86) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01571.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01572.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.93) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01573.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01574.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: ja (0.20) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01575.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01576.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: zh (0.52) in first 30s of audio...
# -> Đã lưu: 0 file.
#
# --- Xử lý: audio01577.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01578.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.28) in first 30s of audio...
#
# --- Xử lý: audio01579.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.95) in first 30s of audio...
#
# --- Xử lý: audio01580.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.23) in first 30s of audio...
#
# --- Xử lý: audio01581.wav ---
# No active speech found in audio
# Warning: audio is shorter than 30s, language detection may be inaccurate.
#
# >>> HOÀN TẤT <<<
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 133
#     130 try:
#     131     # 1. Transcribe
#     132     audio_data = whisperx.load_audio(input_path)
# --> 133     result = model.transcribe(audio_data, batch_size=16)
#     134     detected_lang = result.get("language", "unknown")
#     136     # [FIX] Clear intermediate tensors từ audio
#
# File c:\Users\PC1\anaconda3\envs\whisperx_env\lib\site-packages\whisperx\asr.py:228, in FasterWhisperPipeline.transcribe(self, audio, batch_size, num_workers, language, task, chunk_size, print_progress, combined_progress, verbose)
#     221 vad_segments = merge_chunks(
#     222     vad_segments,
#     223     chunk_size,
#     224     onset=self._vad_params["vad_onset"],
#     225     offset=self._vad_params["vad_offset"],
#     226 )
#     227 if self.tokenizer is None:
# --> 228     language = language or self.detect_language(audio)
#     229     task = task or "transcribe"
#     230     self.tokenizer = Tokenizer(
#     231         self.model.hf_tokenizer,
#     232         self.model.model.is_multilingual,
#     233         task=task,
#     234         language=language,
#     235     )
#
# File c:\Users\PC1\anaconda3\envs\whisperx_env\lib\site-packages\whisperx\asr.py:293, in FasterWhisperPipeline.detect_language(self, audio)
#     289 model_n_mels = self.model.feat_kwargs.get("feature_size")
#     290 segment = log_mel_spectrogram(audio[: N_SAMPLES],
#     291                               n_mels=model_n_mels if model_n_mels is not None else 80,
#     292                               padding=0 if audio.shape[0] >= N_SAMPLES else N_SAMPLES - audio.shape[0])
# --> 293 encoder_output = self.model.encode(segment)
#     294 results = self.model.model.detect_language(encoder_output)
#     295 language_token, language_probability = results[0][0]
#
# File c:\Users\PC1\anaconda3\envs\whisperx_env\lib\site-packages\whisperx\asr.py:96, in WhisperModel.encode(self, features)
#      93     features = np.expand_dims(features, 0)
#      94 features = get_ctranslate2_storage(features)
# ---> 96 return self.model.encode(features, to_cpu=to_cpu)
#
# KeyboardInterrupt:

# %%
import os
import sys
import shutil
import whisperx
import torch
import gc
import pandas as pd
from pydub import AudioSegment
import glob


venv_dir = os.path.dirname(os.path.dirname(sys.executable)) 
cudnn_bin_path = os.path.join(venv_dir, "Lib", "site-packages", "nvidia", "cudnn", "bin")

os.environ["PATH"] = cudnn_bin_path + os.pathsep + os.environ.get("PATH", "")
if hasattr(os, 'add_dll_directory') and os.path.exists(cudnn_bin_path):
    try:
        os.add_dll_directory(cudnn_bin_path)
    except Exception:
        pass

# FFMPEG
FFMPEG_EXE = r"E:\speech_data\SpeechVeri_MultiFeatures\data_preparation\ffmpeg.exe"
FFPROBE_EXE = r"E:\speech_data\SpeechVeri_MultiFeatures\data_preparation\ffprobe.exe"

AudioSegment.converter = FFMPEG_EXE
AudioSegment.ffprobe = FFPROBE_EXE
os.environ["PATH"] = os.path.dirname(FFMPEG_EXE) + os.pathsep + os.environ.get("PATH", "")

def get_processed_files(output_dirs):
    """Quét các file metadata.csv hiện có để lấy danh sách speaker_id đã xong."""
    processed = set()
    for target_dir in output_dirs.values():
        csv_path = os.path.join(target_dir, "metadata.csv")
        if os.path.exists(csv_path):
            try:
                df = pd.read_csv(csv_path)
                if not df.empty:
                    processed.update(df['speaker_id'].astype(str).tolist())
            except Exception as e:
                print(f"[!] Lỗi khi đọc file resume {csv_path}: {e}")
    return processed

def process_audio_pipeline(input_dir, out_dir_3s, out_dir_5s, out_dir_7s, out_dir_non_vi):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    compute_type = "float16" if device == "cuda" else "int8"
    tolerance = 0.5
    
    output_dirs = {3.0: out_dir_3s, 5.0: out_dir_5s, 7.0: out_dir_7s}
    
    for path in list(output_dirs.values()) + [out_dir_non_vi]:
        os.makedirs(path, exist_ok=True)

    # Lấy danh sách các file đã xử lý từ trước
    processed_speakers = get_processed_files(output_dirs)
    
    print(f"[*] Đang load model WhisperX large-v2 trên {device}...")
    model = whisperx.load_model("large-v2", device, compute_type=compute_type)
    # Load model align sẵn để dùng chung (tiết kiệm thời gian)
    align_model_name = "nguyenvulebinh/wav2vec2-base-vietnamese-250h"
    model_a, metadata_align = whisperx.load_align_model(language_code="vi", device=device, model_name=align_model_name)

    wav_files = glob.glob(os.path.join(input_dir, "*.wav"))
    
    # Lọc bỏ các file đã xử lý
    files_to_process = [f for f in wav_files if os.path.basename(f).split('.')[0] not in processed_speakers]
    
    print(f"[*] Tổng cộng: {len(wav_files)} file.")
    print(f"[*] Đã hoàn thành trước đó: {len(processed_speakers)} file.")
    print(f"[*] Cần xử lý tiếp: {len(files_to_process)} file.\n")

    for audio_path in files_to_process:
        base_filename = os.path.basename(audio_path).split('.')[0]
        current_speaker_id = base_filename 
        
        print(f"--- Xử lý: {base_filename}.wav ---")
        
        try:
            audio = whisperx.load_audio(audio_path)
            result = model.transcribe(audio, batch_size=128) # Tăng batch_size nếu GPU mạnh
            lang = result["language"]
            
            if lang != "vi":
                print(f"    -> Non-Vi detected. Moving to non_vi folder.")
                shutil.copy2(audio_path, os.path.join(out_dir_non_vi, os.path.basename(audio_path)))
                continue
            
            # Align
            result = whisperx.align(result["segments"], model_a, metadata_align, audio, device)
            
            words = []
            for segment in result["segments"]:
                for word in segment.get("words", []):
                    if 'start' in word and 'end' in word:
                        words.append(word)
            
            if not words:
                continue

            original_audio = AudioSegment.from_file(audio_path)

            for target_sec, target_dir in output_dirs.items():
                current_metadata = []
                cut_points = [0.0]
                curr_start = 0.0
                valid_count = 0
                
                # Tính toán điểm cắt
                for i in range(len(words) - 1):
                    if (words[i]['end'] - curr_start) >= (target_sec - tolerance):
                        cut_time = (words[i]['end'] + words[i+1]['start']) / 2.0
                        cut_points.append(cut_time)
                        curr_start = cut_time
                
                cut_points.append(words[-1]["end"])

                # Thực hiện cắt và xuất file
                for i in range(len(cut_points) - 1):
                    start_s, end_s = cut_points[i], cut_points[i+1]
                    dur = end_s - start_s
                    
                    if abs(dur - target_sec) <= tolerance:
                        out_name = f"{base_filename}_{int(target_sec)}s_{valid_count+1}.wav"
                        out_path = os.path.join(target_dir, out_name)
                        
                        chunk = original_audio[int(start_s*1000):int(end_s*1000)]
                        chunk.export(out_path, format="wav")
                        
                        txt = " ".join([w['word'] for w in words if w['start'] >= start_s and w['end'] <= end_s])
                        
                        current_metadata.append({
                            "target_duration": target_sec,
                            "speaker_id": current_speaker_id,
                            "filename": out_name,
                            "lang": lang,
                            "duration": round(dur, 3),
                            "start": round(start_s, 3),
                            "end": round(end_s, 3),
                            "text": txt.strip()
                        })
                        valid_count += 1
                
                # Ghi metadata vào CSV ngay lập tức (Append mode)
                if current_metadata:
                    csv_path = os.path.join(target_dir, "metadata.csv")
                    df = pd.DataFrame(current_metadata)
                    # Nếu file chưa tồn tại thì ghi cả header, nếu có rồi thì nối thêm (mode='a') không header
                    df.to_csv(csv_path, mode='a', index=False, header=not os.path.exists(csv_path), encoding='utf-8-sig')
                
                print(f"    + Cắt được {valid_count} đoạn {int(target_sec)}s")

        except Exception as e:
            print(f" [!] Lỗi khi xử lý file {base_filename}: {e}")

    # Dọn dẹp
    del model, model_a
    gc.collect()
    torch.cuda.empty_cache()
    print("\n[*] HOÀN TẤT!")


THU_MUC_GOC = r"D:\my_project\SLP301-data\test_data\test_set_O\wav"  
THU_MUC_3S  = r"D:\my_project\SLP301-data\test_data\test_set_O\test_o_cut_3s"
THU_MUC_5S  = r"D:\my_project\SLP301-data\test_data\test_set_O\test_o_cut_5s"
THU_MUC_7S  = r"D:\my_project\SLP301-data\test_data\test_set_O\test_o_cut_7s"
THU_MUC_NON_VI = r"D:\my_project\SLP301-data\test_data\test_set_O\test_o_non_vi"

process_audio_pipeline(THU_MUC_GOC, THU_MUC_3S, THU_MUC_5S, THU_MUC_7S, THU_MUC_NON_VI)
# Out:
# [*] Đang load model WhisperX large-v2 trên cpu...
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.5.1.post0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint c:\Users\PC1\anaconda3\envs\whisperx_env\lib\site-packages\whisperx\assets\pytorch_model.bin`
# No language specified, language will be first be detected for each audio file (increases inference time).
# >>Performing voice activity detection using Pyannote...
# Model was trained with pyannote.audio 0.0.1, yours is 3.3.2. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.7.0+cpu. Bad things might happen unless you revert torch to 1.x.
# c:\Users\PC1\anaconda3\envs\whisperx_env\lib\site-packages\transformers\configuration_utils.py:312: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# [*] Tổng cộng: 20168 file.
# [*] Đã hoàn thành trước đó: 1039 file.
# [*] Cần xử lý tiếp: 19129 file.
#
# --- Xử lý: audio00004.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00006.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00008.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00010.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00012.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00014.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00018.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00038.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00040.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00046.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00048.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00050.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00054.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00058.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.97) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00060.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00062.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00068.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00072.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00080.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00086.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00092.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00094.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00100.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00102.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.96) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00108.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00114.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00116.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.97) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00118.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00144.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00150.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00156.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00158.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00160.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00172.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00180.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00182.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00196.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00198.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00204.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00206.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.98) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00210.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00212.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00216.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00218.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00222.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00224.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00226.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00228.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00236.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00246.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (1.00) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00248.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.97) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00253.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00255.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00257.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00259.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00260.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00261.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00263.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00265.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00267.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00269.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00271.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00273.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00275.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00277.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00278.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00279.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00281.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00283.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00285.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00287.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00289.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00291.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00293.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00295.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00297.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00299.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00301.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00303.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00305.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00306.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00307.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00309.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00311.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00312.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00313.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00314.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00315.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00317.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00319.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00321.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00323.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00325.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00326.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00327.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00329.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00331.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00333.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00334.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00335.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00337 (1).wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00337(1).wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00337(2).wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00337(3).wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00337.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00338.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00339.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00341.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00343.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00345.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00347.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00349.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00350.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00351.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00353.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00355.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00357.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00359.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00360.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00361.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00363.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00365.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00367.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00369.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00371.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00373.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00375.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00377.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00379.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00380.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00381.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00384.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00386.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00388.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00390.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00392.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: zh (0.16) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00394.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00396.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00398.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00402.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: he (0.29) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00404.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00406.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00408.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00410.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00412.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: zh (0.42) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00414.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00416.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00418.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00420.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: mi (0.68) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio00424.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00426.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00428.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00430.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00432.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00468.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00474.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00498.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00514.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00528.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00546.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00550.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00568.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00572.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00574.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00582.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00626.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00666.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00692.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00710.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00732.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00740.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00742.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00746.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00754.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00764.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00774.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00784.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00794.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.97) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00798.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00808.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00816.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.96) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00830.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00840.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00848.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00850.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00862.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00896.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00904.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00910.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00922.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00954.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio00962.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio01018.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio01040.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio01052.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio01060.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio01074.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio01102.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio01116.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio01128.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio01132.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio01138.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.98) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio01140.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio01146.wav ---
# ...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21927.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 4 đoạn 3s
#     + Cắt được 2 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21928.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21929.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 3 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21930.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 10 đoạn 3s
#     + Cắt được 5 đoạn 5s
#     + Cắt được 4 đoạn 7s
# --- Xử lý: audio21931.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21932.wav ---
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 12 đoạn 3s
#     + Cắt được 7 đoạn 5s
#     + Cắt được 5 đoạn 7s
# --- Xử lý: audio21933.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21934.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21935.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21936.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21937.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 2 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21938.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21939.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21940.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21941.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21942.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21943.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21944.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21945.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 3 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21946.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21947.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 3 đoạn 3s
#     + Cắt được 2 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21948.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21949.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21950.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21951.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21952.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21953.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio21954.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.98) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio21955.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21956.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 3 đoạn 3s
#     + Cắt được 2 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21957.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 3 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21958.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21959.wav ---
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 15 đoạn 3s
#     + Cắt được 8 đoạn 5s
#     + Cắt được 6 đoạn 7s
# --- Xử lý: audio21960.wav ---
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 13 đoạn 3s
#     + Cắt được 6 đoạn 5s
#     + Cắt được 5 đoạn 7s
# --- Xử lý: audio21961.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21962.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21963.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21964.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21965.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21966.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21967.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 7 đoạn 3s
#     + Cắt được 4 đoạn 5s
#     + Cắt được 2 đoạn 7s
# --- Xử lý: audio21968.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 5 đoạn 3s
#     + Cắt được 3 đoạn 5s
#     + Cắt được 2 đoạn 7s
# --- Xử lý: audio21969.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 4 đoạn 3s
#     + Cắt được 2 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21970.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21971.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 4 đoạn 3s
#     + Cắt được 2 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21972.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21973.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 3 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21974.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 6 đoạn 3s
#     + Cắt được 3 đoạn 5s
#     + Cắt được 2 đoạn 7s
# --- Xử lý: audio21975.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21976.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 3 đoạn 3s
#     + Cắt được 2 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21977.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21978.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21979.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 4 đoạn 3s
#     + Cắt được 2 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21980.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21981.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21982.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 0 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21983.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21984.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21985.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21986.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 1 đoạn 3s
#     + Cắt được 0 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21987.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.85) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio21988.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.82) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio21989.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (0.99) in first 30s of audio...
#     + Cắt được 3 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 1 đoạn 7s
# --- Xử lý: audio21990.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21991.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio21992.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.98) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio21993.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 2 đoạn 3s
#     + Cắt được 1 đoạn 5s
#     + Cắt được 0 đoạn 7s
# --- Xử lý: audio21994.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: vi (1.00) in first 30s of audio...
#     + Cắt được 6 đoạn 3s
#     + Cắt được 3 đoạn 5s
#     + Cắt được 2 đoạn 7s
# --- Xử lý: audio21995.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
# --- Xử lý: audio21996.wav ---
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: en (0.99) in first 30s of audio...
#     -> Non-Vi detected. Moving to non_vi folder.
#
# [*] HOÀN TẤT!
