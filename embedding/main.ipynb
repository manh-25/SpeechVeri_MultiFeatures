# %% [markdown]
# ### Kích hoạt tự động load lại code. Nếu sửa code trong embedding.py, Notebook sẽ tự động cập nhật mà không cần restart kernel.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Import và chạy trích embedding

# %%
from embedding import run_extraction

# Cấu hình đường dẫn
DATA_DIR = r"D:\my_project\SLP301-data\train_raw"
MODELS = ["wavlm", "hubert", "wav2vec2"]

for m in MODELS:
    output_name = f"{m}_all_layers.pt"
    run_extraction(model_key=m, folder_path=DATA_DIR, save_path=output_name, batch_size=16)
# Out:
# --- Đang chạy wavlm trên cuda ---
#  23%|██▎       | 7389/32271 [1:54:36<6:25:56,  1.07it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
#       7 for m in MODELS:
#       8     output_name = f"{m}_all_layers.pt"
# ----> 9     run_extraction(model_key=m, folder_path=DATA_DIR, save_path=output_name, batch_size=8)
#
# File c:\Users\PC1\anaconda3\envs\ai_env\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File e:\speech_data\SpeechVeri_MultiFeatures\embedding\embedding.py:85, in run_extraction(model_key, folder_path, save_path, batch_size)
#      83 print(f"--- Đang chạy {model_key} trên {device} ---")
#      84 # Cơ chế "Streaming" cho .pt (Lưu nháp nếu cần, ở đây tối ưu hóa RAM list)
# ---> 85 for i, (waveforms, ids, names) in enumerate(tqdm(dataloader)):
#      86     waveforms_numpy = [w.numpy() for w in waveforms]
#      88     # Ép kiểu input về half ngay khi vào model
#
# File c:\Users\PC1\anaconda3\envs\ai_env\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\PC1\anaconda3\envs\ai_env\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\PC1\anaconda3\envs\ai_env\lib\site-packages\transformers\models\wavlm\modeling_wavlm.py:1076, in WavLMModel.forward(self, input_values, attention_mask, mask_time_indices, output_attentions, output_hidden_states, return_dict)
#    1072 extract_features = extract_features.transpose(1, 2)
#    1074 if attention_mask is not None:
#    1075     # compute reduced attention_mask corresponding to feature vectors
# -> 1076     attention_mask = self._get_feature_vector_attention_mask(
#    1077         extract_features.shape[1], attention_mask, add_adapter=False
#    1078     )
#    1080 hidden_states, extract_features = self.feature_projection(extract_features)
#    1081 hidden_states = self._mask_hidden_states(
#    1082     hidden_states, mask_time_indices=mask_time_indices, attention_mask=attention_mask
#    1083 )
#
# File c:\Users\PC1\anaconda3\envs\ai_env\lib\site-packages\transformers\models\wavlm\modeling_wavlm.py:678, in WavLMPreTrainedModel._get_feature_vector_attention_mask(self, feature_vector_length, attention_mask, add_adapter)
#     676 # these two operations makes sure that all values before the output lengths idxs are attended to
#     677 attention_mask[(torch.arange(attention_mask.shape[0], device=attention_mask.device), output_lengths - 1)] = 1
# --> 678 attention_mask = attention_mask.flip([-1]).cumsum(-1).flip([-1]).bool()
#     679 return attention_mask
#
# KeyboardInterrupt:

# %% [markdown]
# ### Kiểm tra thử dữ liệu sau khi lưu

# %%
import torch

data = torch.load("wavlm_all_layers.pt")
print(f"--- Thông tin trích xuất ---")
print(f"Mô hình gốc: {data['model_name']}")
print(f"Số lượng mẫu (N): {len(data['filenames'])}")
print(f"Kích thước Tensor: {data['embeddings'].shape}")

# Kiểm tra thử mẫu đầu tiên
print(f"\nMẫu đầu tiên:")
print(f" - File: {data['filenames'][0]}")
print(f" - ID người nói: {data['speaker_ids'][0]}")
print(f" - Vector tầng cuối (5 giá trị đầu): {data['embeddings'][0, 12, :5]}")

# %%
data = torch.load("hubert_all_layers.pt")
print(f"--- Thông tin trích xuất ---")
print(f"Mô hình gốc: {data['model_name']}")
print(f"Số lượng mẫu (N): {len(data['filenames'])}")
print(f"Kích thước Tensor: {data['embeddings'].shape}")

# Kiểm tra thử mẫu đầu tiên
print(f"\nMẫu đầu tiên:")
print(f" - File: {data['filenames'][0]}")
print(f" - ID người nói: {data['speaker_ids'][0]}")
print(f" - Vector tầng cuối (5 giá trị đầu): {data['embeddings'][0, 12, :5]}")

# %%
data = torch.load("wav2vec2_all_layers.pt")
print(f"--- Thông tin trích xuất ---")
print(f"Mô hình gốc: {data['model_name']}")
print(f"Số lượng mẫu (N): {len(data['filenames'])}")
print(f"Kích thước Tensor: {data['embeddings'].shape}")

# Kiểm tra thử mẫu đầu tiên
print(f"\nMẫu đầu tiên:")
print(f" - File: {data['filenames'][0]}")
print(f" - ID người nói: {data['speaker_ids'][0]}")
print(f" - Vector tầng cuối (5 giá trị đầu): {data['embeddings'][0, 12, :5]}")
